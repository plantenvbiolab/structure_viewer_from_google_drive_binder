# %%
using Downloads

# %%
using BioStructures

# %%
using Bio3DView

# %%
using Blink

# %%
file_id = "16wPdAzV0CFPxYcX0-msK_q9R8YHnHV0P"

# %%
url = "https://drive.google.com/uc?export=download&id=$file_id"

# %%
Downloads.download(url,"temp.pdb")

# %%
struc = read("temp.pdb", PDBFormat)

# %%
viewstruc(struc[1])

# %%
rm("temp.pdb")
