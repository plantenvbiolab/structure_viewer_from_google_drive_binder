# %%
using Downloads

# %%
using BioStructures

# %%
using Bio3DView

# %%
using Blink

# %%
sharing_url = "https://drive.google.com/file/d/16wPdAzV0CFPxYcX0-msK_q9R8YHnHV0P/view?usp=sharing"

# %%
file_id =  split(split(sharing_url, "/d/")[2], "/")[1]

# %%
download_url = "https://drive.google.com/uc?export=download&id=$file_id"

# %%
Downloads.download(download_url,"temp.pdb")

# %%
struc = read("temp.pdb", PDBFormat)

# %%
viewstruc(struc[1])

# %%
rm("temp.pdb")
